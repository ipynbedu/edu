# %% [markdown]
# # 🔰 U0. 시작하기 전에 — 코드 구경하기
#
# 문법은 아직 하나도 몰라도 됩니다. 이번 유닛은 딱 하나만 합니다 — **실제 AICE Associate 시험에 그대로
# 나온 코드**를 눈으로 구경하고, 한 줄은 직접 실행까지 해보는 것.

# %% [markdown]
# 회색 상자를 **코드 셀**이라고 합니다. 코드 셀을 클릭하고 `Shift + Enter`를 누르면 그 코드가 실행되고, 바로 아래에 결과가 나타납니다. 노트북은 이런 셀들이 위에서 아래로 이어진 문서입니다.

# %% [markdown]
# 아래는 실제 AICE Associate 시험 **문제 1번**에 그대로 나온 코드입니다. 뜻은 몰라도 됩니다 — 직접 실행해서 "방금 진짜 시험 코드를 실행해봤다"는 감각만 가져가세요.

# %%
import sklearn as sk

# %% [markdown]
# 실행됐는데 아무것도 안 나왔다고 걱정하지 마세요 — 원래 그렇습니다. 아래 두 줄도 각각 실제 시험 **문제 2번**, **문제 4번**에 그대로 나온 코드입니다. 지금은 실행하지 말고 그냥 눈으로만 보세요.
#
# ```python
# data.head(4)
# ```
#
# ```python
# sns.boxplot(data=data, x='Grade', y='FE_points_winery')
# ```

# %% [markdown]
# 지금 알아야 할 건 이것뿐입니다 — **코드는 위에서 아래로 실행되고, `read_csv`·`head`·`boxplot` 같은 이름들은 각각 정해진 한 가지 일을 하는 "명령어"**라는 것. 이 명령어들이 왜 이렇게 생겼는지는 다음 유닛부터 하나씩 배웁니다.
#
# 다음: **U1. 변수와 자료형**
