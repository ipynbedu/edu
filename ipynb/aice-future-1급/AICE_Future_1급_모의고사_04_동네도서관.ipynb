# %% [markdown]
# # AICE Future 1급 모의고사 (고급)
#
# - 시험 시간: 60분 · 문항수: 8문항 · 응시료(참고): 50,000원
# - 합격선: 100점 만점에 **60점 이상**
# - 이번 회차 소재: **동네 도서관**
#
# 실제 AICE Future 시험은 'AI 코디니' 블록코딩 툴로 진행되며 문법 코드를 직접 타이핑하지 않습니다. 이 노트북은 시험이 요구하는 개념(이론/데이터 관리/AI 활용/머신러닝/코딩 논리)을 그대로 퀴즈로 옮긴 학습용 모의고사이며, 정답 확인 후 일부 문항에는 이 개념이 실제 Python 코드로는 어떻게 보이는지 보너스로 덧붙였습니다.
#
# **사용법**: 아래 '문제' 섹션의 각 `answers[N] = None`을 정답으로 바꿔 실행한 뒤, 맨 아래 '채점' 셀을 실행하면 점수를 바로 확인할 수 있습니다. 먼저 스스로 풀어보고, '해설' 섹션은 채점 후에 참고하세요.

# %%
# 답안을 저장할 딕셔너리 (아래 문제들에서 채워나갑니다)
answers = {}

# %% [markdown]
# ---
# ## 문제

# %% [markdown]
# ### 1번. [코딩심화] 여러 데이터 형식을 처리하는 순서  <sub>(15점)</sub>
#
# 표, 사진, 글이 섞인 데이터를 처리하는 블록코딩을 만들 때, 다음 네 단계의 올바른 순서는?

# %% [markdown]
# **보기**
#
# - **A**: 입력 데이터 형식(표/사진/글) 확인하기
# - **B**: 형식별로 알맞은 처리 블록 나누어 적용하기
# - **C**: 처리된 결과들을 하나로 합치기
# - **D**: 최종 결과 출력하기

# %%
# 1번 정답을 입력하세요 (보기 라벨을 올바른 순서로 나열, 예: ['A','B','C','D'])
answers[1] = None

# %% [markdown]
# ### 2번. [데이터 관리] 이상치가 미치는 영향  <sub>(10점)</sub>
#
# 동네 도서관의 '대출 건수' 기록 중 하루치가 다른 날들보다 비정상적으로 크거나 작은 값(이상치)이다. 이를 그대로 두고 AI를 학습시키면 어떤 영향이 있을까?

# %% [markdown]
# 1. 그 이상치 하나 때문에 AI의 예측이 한쪽으로 치우칠 수 있다
# 2. 이상치는 AI 학습에 전혀 영향을 주지 않는다
# 3. 이상치가 있으면 AI가 자동으로 무시해준다
# 4. 이상치가 많을수록 AI가 항상 더 정확해진다

# %%
# 2번 정답을 입력하세요 (보기 번호 1~4 중 하나)
answers[2] = None

# %% [markdown]
# ### 3번. [머신러닝] 상황에 맞는 학습 방식 고르기  <sub>(15점)</sub>
#
# 동네 도서관에서 '방문객을 비슷한 성향끼리 자동으로 몇 개 무리로 나누고 싶다(정답 그룹표는 없음)'는 목표가 있다. 가장 알맞은 학습 방식은?

# %% [markdown]
# 1. 비지도학습(군집화)
# 2. 지도학습(분류)
# 3. 회귀
# 4. 학습이 필요 없다

# %%
# 3번 정답을 입력하세요 (보기 번호 1~4 중 하나)
answers[3] = None

# %% [markdown]
# ### 4번. [이론] 정형 데이터 vs 비정형 데이터  <sub>(10점)</sub>
#
# '표(엑셀)처럼 행과 열로 깔끔하게 정리된 데이터'와 '사진, 음성, 글처럼 정해진 틀이 없는 데이터'를 각각 부르는 말로 알맞은 것은?

# %% [markdown]
# 1. 정형 데이터 / 비정형 데이터
# 2. 큰 데이터 / 작은 데이터
# 3. 옛날 데이터 / 새 데이터
# 4. 비싼 데이터 / 싼 데이터

# %%
# 4번 정답을 입력하세요 (보기 번호 1~4 중 하나)
answers[4] = None

# %% [markdown]
# ### 5번. [머신러닝] 회귀 예측 결과 해석하기  <sub>(15점)</sub>
#
# AI가 '내일 동네 도서관의 대출 건수는 52가 될 것이다'라고 예측했는데, 실제로는 47이었다. 이 상황을 가장 알맞게 설명한 것은?

# %% [markdown]
# 1. 예측값(52)과 실제값(47) 사이에 5만큼 차이(오차)가 있다
# 2. AI가 완전히 고장난 것이다
# 3. 이 AI는 절대 다시 쓸 수 없다
# 4. 예측값과 실제값은 항상 정확히 같아야만 정상이다

# %%
# 5번 정답을 입력하세요 (보기 번호 1~4 중 하나)
answers[5] = None

# %% [markdown]
# ### 6번. [AI 활용] 여러 AI 기술이 결합된 서비스  <sub>(15점)</sub>
#
# '동네 도서관에 온 손님의 목소리로 주문을 받고, 동시에 사진으로 혼잡한 정도를 파악하는' 서비스를 만들려고 한다. 이 서비스에는 서로 다른 AI 인식 기술이 몇 가지 함께 쓰이는가?

# %% [markdown]
# 1. 2가지 (음성 인식 + 이미지 인식)
# 2. 1가지뿐이다
# 3. AI가 아니라 사람이 하는 일이다
# 4. 인식 기술은 전혀 필요 없다

# %%
# 6번 정답을 입력하세요 (보기 번호 1~4 중 하나)
answers[6] = None

# %% [markdown]
# ### 7번. [데이터 관리] 형식이 섞인 데이터 다루기  <sub>(10점)</sub>
#
# 동네 도서관에서 '대출 건수' 같은 표 데이터와 함께 손님이 남긴 사진·후기 글까지 함께 분석하려 한다. 형식이 섞였을 때 가장 먼저 해야 할 일로 알맞은 것은?

# %% [markdown]
# 1. 각 데이터 형식(표/사진/글)이 무엇을 의미하는지 파악하고 형식별로 정리 방법을 따로 정하기
# 2. 무조건 사진부터 전부 지우기
# 3. 글자 데이터는 분석 대상이 아니므로 무시하기
# 4. 아무 정리 없이 형식이 다른 데이터를 한꺼번에 AI에 넣기

# %%
# 7번 정답을 입력하세요 (보기 번호 1~4 중 하나)
answers[7] = None

# %% [markdown]
# ### 8번. [이론] 이미지를 다르게 다루는 이유  <sub>(10점)</sub>
#
# 사진(이미지) 데이터를 표(정형) 데이터와 다르게 다뤄야 하는 이유로 가장 알맞은 것은?

# %% [markdown]
# 1. 사진은 수많은 점(픽셀)의 색깔 값으로 이루어져 있어 표의 행/열처럼 바로 정리되지 않기 때문에
# 2. 사진은 용량이 항상 표 데이터보다 작기 때문에
# 3. 사진은 AI가 아예 다룰 수 없는 형식이기 때문에
# 4. 사진은 항상 표 데이터보다 예쁘기 때문에

# %%
# 8번 정답을 입력하세요 (보기 번호 1~4 중 하나)
answers[8] = None

# %% [markdown]
# ---
# ## 해설
#
# 스스로 풀어본 뒤 아래에서 확인하세요. 문항 번호가 위 문제 번호와 일치합니다.

# %% [markdown]
# ### 1번 해설 - [코딩심화] 여러 데이터 형식을 처리하는 순서

# %%
answers[1] = ['A', 'B', 'C', 'D']  # 모범답안 순서

# %% [markdown]
# > 여러 형식의 데이터를 다룰 때는 먼저 형식을 확인하고, 형식별로 처리한 뒤, 결과를 합쳐서 최종 출력하는 순서가 자연스럽습니다.

# %% [markdown]
# **실제 코드로 보면 (보너스: Associate 단계 미리보기)**

# %%
# 형식별 처리 -> 결과 합치기를 실제 코드로 보면
table_result = '표 데이터 정리 완료'
image_result = '사진 분석 완료'
text_result = '글 분석 완료'
final_result = [table_result, image_result, text_result]  # 결과 합치기
print('최종 결과:', final_result)

# %% [markdown]
# ### 2번 해설 - [데이터 관리] 이상치가 미치는 영향

# %%
answers[2] = 1  # 모범답안: 그 이상치 하나 때문에 AI의 예측이 한쪽으로 치우칠 수 있다

# %% [markdown]
# > 이상치(비정상적으로 크거나 작은 값)를 그대로 두면 AI가 그 값에 영향을 받아 예측이 한쪽으로 치우치는 등 왜곡될 수 있습니다.

# %% [markdown]
# ### 3번 해설 - [머신러닝] 상황에 맞는 학습 방식 고르기

# %%
answers[3] = 1  # 모범답안: 비지도학습(군집화)

# %% [markdown]
# > 정답이 되는 그룹표 없이 비슷한 것끼리 스스로 묶는 목표이므로 비지도학습(군집화)이 알맞습니다.

# %% [markdown]
# **실제 코드로 보면 (보너스: Associate 단계 미리보기)**

# %%
# 군집화(KMeans)를 실제 코드로 보면
from sklearn.cluster import KMeans
import pandas as pd
df = pd.DataFrame({'방문횟수': [1, 2, 8, 9, 1, 8], '체류시간': [5, 6, 40, 42, 4, 39]})
model = KMeans(n_clusters=2, n_init=10, random_state=0).fit(df)
print('그룹 결과:', model.labels_)  # 정답표 없이 스스로 2개 그룹으로 나눈 결과

# %% [markdown]
# ### 4번 해설 - [이론] 정형 데이터 vs 비정형 데이터

# %%
answers[4] = 1  # 모범답안: 정형 데이터 / 비정형 데이터

# %% [markdown]
# > 행과 열로 정리된 데이터를 정형 데이터, 사진·음성·글처럼 정해진 형식이 없는 데이터를 비정형 데이터라고 합니다.

# %% [markdown]
# ### 5번 해설 - [머신러닝] 회귀 예측 결과 해석하기

# %%
answers[5] = 1  # 모범답안: 예측값(52)과 실제값(47) 사이에 5만큼 차이(오차)가 있다

# %% [markdown]
# > 회귀 예측은 실제값과 정확히 똑같이 맞히기보다, 예측값과 실제값의 차이(오차)가 얼마나 작은지로 성능을 판단합니다. 5만큼의 차이는 하나의 오차값일 뿐입니다.

# %% [markdown]
# **실제 코드로 보면 (보너스: Associate 단계 미리보기)**

# %%
# 예측 오차를 실제 코드로 계산해보면
predicted = 52
actual = 47
error = abs(predicted - actual)
print(f'오차: {error}')  # 값이 작을수록 잘 예측한 것입니다

# %% [markdown]
# ### 6번 해설 - [AI 활용] 여러 AI 기술이 결합된 서비스

# %%
answers[6] = 1  # 모범답안: 2가지 (음성 인식 + 이미지 인식)

# %% [markdown]
# > 목소리를 알아듣는 음성 인식과 사진을 분석하는 이미지 인식, 두 가지 서로 다른 AI 인식 기술이 함께 결합된 서비스입니다.

# %% [markdown]
# ### 7번 해설 - [데이터 관리] 형식이 섞인 데이터 다루기

# %%
answers[7] = 1  # 모범답안: 각 데이터 형식(표/사진/글)이 무엇을 의미하는지 파악하고 형식별로 정리 방법을 따로 정하기

# %% [markdown]
# > 형식이 다른 데이터를 함께 다룰 때는 각 형식이 어떤 의미인지 파악하고, 형식별로 알맞은 정리 방법을 따로 정하는 것이 먼저입니다.

# %% [markdown]
# ### 8번 해설 - [이론] 이미지를 다르게 다루는 이유

# %%
answers[8] = 1  # 모범답안: 사진은 수많은 점(픽셀)의 색깔 값으로 이루어져 있어 표의 행/열처럼 바로 정리되지 않기 때문에

# %% [markdown]
# > 이미지는 수많은 픽셀 값들로 이루어져 있어, 표처럼 바로 행/열로 정리되는 정형 데이터와는 다른 방식(예: 픽셀값 배열)으로 다뤄야 합니다.

# %% [markdown]
# ---
# ## 채점

# %%
# 채점: 문제를 푼 뒤(또는 해설 셀을 실행한 뒤) 이 셀을 실행하세요.
_key = {
    1: ['A', 'B', 'C', 'D'],
    2: 1,
    3: 1,
    4: 1,
    5: 1,
    6: 1,
    7: 1,
    8: 1,
}
_points = {
    1: 15,
    2: 10,
    3: 15,
    4: 10,
    5: 15,
    6: 15,
    7: 10,
    8: 10,
}
_pass_score = 60
_total = 100
_score = sum(_points[n] for n, correct in _key.items() if answers.get(n) == correct)
_result = '합격' if _score >= _pass_score else '불합격'
print(f'1급 모의고사 채점 결과: {_score} / {_total}점 -> {_result} (합격선 {_pass_score}점)')
for n in sorted(_key):
    ok = '✅' if answers.get(n) == _key[n] else ('⬜' if answers.get(n) is None else '❌')
    print(f'  {ok} {n}번  내 답: {answers.get(n)}  /  정답: {_key[n]}')
