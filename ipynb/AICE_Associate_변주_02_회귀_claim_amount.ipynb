# %% [markdown]
# # AICE Associate 변주 문제 - 사기 발생 여부,정상 청구 금액 예측 (회귀)

# %% [markdown]
# ### 이 노트북의 구성요소
#
# 아래 다이어그램은 이 노트북 해설에서 실제로 사용된 함수·클래스·모듈을 구간별로 모은 것입니다 (굵게 표시된 이름은 이 노트북에서 특별히 선택된 항목입니다).

# %%
from IPython.display import HTML, display

display(HTML("""
<script src="https://cdn.jsdelivr.net/npm/mermaid@10/dist/mermaid.min.js"></script>

<div style="display:flex; flex-direction:column; gap:6px; width:fit-content;">
<pre class="mermaid">
flowchart LR
    subgraph LIB["라이브러리"]
        LIB1["<b>라이브러리</b><br/>sklearn"]
    end
    subgraph EXP["데이터 탐색"]
        EXP1["<b>데이터 탐색</b><br/>head<br/>read_csv"]
    end
    subgraph PREP["전처리"]
        PREP1["<b>전처리</b><br/><b>StandardScaler</b><br/>LabelEncoder<br/>drop<br/>dropna<br/>train_test_split"]
    end
    LIB --> EXP --> PREP
    classDef libCls fill:#F0EEE8,stroke:#8A8478,color:#3A362E
    class LIB libCls
    classDef expCls fill:#E9F1F6,stroke:#5B7C99,color:#1E3548
    class EXP expCls
    classDef prepCls fill:#FAF3E7,stroke:#B08D57,color:#5C4720
    class PREP prepCls
</pre>
<pre class="mermaid">
flowchart LR
    subgraph ML["머신러닝"]
        ML1["<b>머신러닝</b><br/><b>RandomForestRegressor</b><br/><b>mean_absolute_error</b><br/>DataFrame<br/>DecisionTreeRegressor<br/>GridSearchCV<br/>sort_values"]
    end
    subgraph UNSUP["비지도학습"]
        UNSUP1["<b>비지도학습</b><br/>(기본 구성)"]
    end
    subgraph DL["딥러닝"]
        DL1["<b>딥러닝</b><br/>(기본 구성)"]
    end
    ML --> UNSUP --> DL
    classDef mlCls fill:#FBEEEA,stroke:#B5654A,color:#5C2A1B
    class ML mlCls
    classDef unsupCls fill:#F3EEF4,stroke:#8B6F8E,color:#402F42
    class UNSUP unsupCls
    classDef dlCls fill:#EBEEF6,stroke:#445577,color:#232C3D
    class DL dlCls
</pre>
</div>

<script>
mermaid.initialize({ startOnLoad: false, securityLevel: "loose" });
mermaid.run();
</script>
"""))

# %% [markdown]
# ### 시나리오
#
# AICE 보험사는 연간 보험금 청구 데이터에서 사기 가능성이 높은 손해액을 예측하여 보험금 지급의 적정성을 평가하고자 합니다. 이 모델은 잠재적인 사기 위험이 높은 고객 및 사고 유형을 식별하고, 이를 통해 보험금 지급 프로세스의 효율성과 정확성을 높이는 것을 목표로 합니다.
#
# ---
#
# **[유의사항]**
# - 답안은 각 문항 아래 표시된 `# (N) 여기에 ...` 칸에 작성하세요.
# - **정답/해설은 이 노트북 가장 아래 `## 해설` 섹션에 모아뒀습니다.** 먼저 스스로 풀어본 뒤에 확인하세요.
# - 이 노트북은 오리지널 창작 문제이며, 실제 AICE 샘플문항 원문을 복제하지 않습니다.

# %% [markdown]
# **[데이터 컬럼 설명]**
#
# - claim_amount : 사기 발생 여부,정상 청구 금액
# - total_claim_amount : 특정 기간 동안 발생한 총 보험금 청구액
# - policy_type : 차량 종류(승용차,트럭,SUV),보험 계약 유형(개인,법인,영업)
# - driver_age : 피처 컬럼
# - accident_severity_score : 피처 컬럼
# - claim_frequency : 피처 컬럼
# - deductible_level : 피처 컬럼
# - location_risk_index : 피처 컬럼
# - policy_id : 식별자(모델링에 불필요)

# %% [markdown]
# ## 0. 데이터 준비
#
# 다음 문항을 풀기 전에 아래 코드를 실행하세요(문제 데이터를 생성합니다).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


def synthesize_dataframe(seed=0, n_rows=600):
    rng = np.random.default_rng(seed)
    n = n_rows

    base = rng.normal(loc=50, scale=15, size=n)
    outlier_idx = rng.choice(n, size=max(3, n // 50), replace=False)
    base[outlier_idx] += rng.choice([1, -1], size=len(outlier_idx)) * rng.uniform(80, 150, size=len(outlier_idx))

    df = pd.DataFrame({'total_claim_amount': base.round(2)})
    n_cats = rng.integers(3, 5)
    cats = [f"Type{i+1}" for i in range(n_cats)]
    df['policy_type'] = rng.choice(cats, size=n)

    for col in ['driver_age', 'accident_severity_score', 'claim_frequency', 'deductible_level', 'location_risk_index']:
        df[col] = rng.normal(0, 1, size=n).round(2)

    df['policy_id'] = [f"ID{i:05d}" for i in range(n)]

    z = (base - base.mean()) / (base.std() + 1e-9)
    if '회귀' == "분류":
        prob = 1 / (1 + np.exp(-z))
        labels = (rng.random(n) < prob).astype(int)
        classes = [c.strip() for c in '사기 발생 여부,정상 청구 금액'.split(",") if c.strip()][:2]
        if len(classes) < 2:
            classes = ["Positive", "Negative"]
        df['claim_amount'] = np.where(labels == 1, classes[0], classes[-1])
    else:
        noise = rng.normal(0, 5, size=n)
        df['claim_amount'] = (base * 1.5 + noise).round(2)

    for col in ['total_claim_amount'] + ['driver_age', 'accident_severity_score', 'claim_frequency', 'deductible_level', 'location_risk_index'][:2]:
        na_idx = rng.choice(n, size=int(n * 0.03), replace=False)
        df.loc[na_idx, col] = np.nan

    return df.sample(frac=1, random_state=seed).reset_index(drop=True)


data = synthesize_dataframe(seed=1001)
data.to_csv("data.csv", index=False)
print("data.csv 저장 완료 -", data.shape)
data.head(4)

# %% [markdown]
# ## <데이터 분석>

# %% [markdown]
# ### 1. 라이브러리 임포트
#
# scikit-learn 을 alias **sk** 로 임포트하세요.

# %%
# (1) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 2. 데이터 로드
#
# pandas 로 'data.csv' 를 읽어와 데이터프레임 변수명 **my_data** 에 할당하고, 첫 4개 행을 출력하세요.

# %%
# (2) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 3. 시각화 (subplots)
#
# 차량 종류(승용차,트럭,SUV),보험 계약 유형(개인,법인,영업)(policy_type) 분포의 countplot 과, 사기 발생 여부,정상 청구 금액 별 특정 기간 동안 발생한 총 보험금 청구액(total_claim_amount) histplot 을 나란히 그리는 코드입니다.
# 빈칸 **(A)** 에 들어갈, 여러 그래프를 한 번에 그릴 때 쓰는 matplotlib 함수 이름은?
#
# ```python
# fig, axes = plt.(A)(nrows=1, ncols=2, figsize=(12, 5))
# sns.countplot(data=my_data, x='policy_type', ax=axes[0])
# sns.histplot(data=my_data, x='total_claim_amount', hue='claim_amount', ax=axes[1])
# plt.show()
# ```

# %%
# (3) 여기에 답을 입력하세요 (실행 불필요)

# %% [markdown]
# ### 4. 시각화 (boxplot)
#
# 사기 발생 여부,정상 청구 금액 별 특정 기간 동안 발생한 총 보험금 청구액(total_claim_amount) 의 분포를 seaborn boxplot 으로 시각화하세요 (X축: 타깃, Y축: 수치형 컬럼).

# %%
# (4) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ## <데이터 전처리>

# %% [markdown]
# ### 5. 이상치 처리
#
# 특정 기간 동안 발생한 총 보험금 청구액(total_claim_amount) 컬럼의 IQR 기준(K=1.0)을 벗어나는 이상치 행을 제거하고, 불필요한 컬럼(policy_id)도 삭제해서 **data_temp** 에 저장하는 코드입니다. 빈칸 **(A)** 에 들어갈, 행을 삭제할 때 쓰는 DataFrame 메서드 이름은?
#
# ```python
# q1 = my_data['total_claim_amount'].quantile(0.25)
# q3 = my_data['total_claim_amount'].quantile(0.75)
# iqr = q3 - q1
# lower_fence = q1 - 1.0 * iqr
# upper_fence = q3 + 1.0 * iqr
# data_temp = my_data.(A)(my_data[(my_data['total_claim_amount'] > upper_fence) | (my_data['total_claim_amount'] < lower_fence)].index)
# data_temp = data_temp.drop(columns=['policy_id'])
# data_temp = data_temp.reset_index(drop=True)
# ```

# %%
# (5) 여기에 답을 입력하세요 (실행 불필요)

# %% [markdown]
# ### 6. 결측치 처리
#
# 다음은 data_temp 의 결측치를 처리하는 코드인데, 실행하면 의도한 것과 다르게 동작합니다. 무엇이 문제인지 서술하거나, 올바르게 고친 코드를 작성하세요.
#
# ```python
# print('결측치 처리 전')
# print(data_temp.isnull().sum())
# if data_temp.shape[0] > 0:
#     data_na = data_temp.dropna()
#     print('결측치 처리 후')
#     print(data_na.isnull().sum())
# else:
#     print('데이터프레임이 비어있습니다.')
# ```

# %%
# (6) 여기에 문제점 설명 또는 수정한 코드를 작성하세요

# %% [markdown]
# ### 7. 인코딩
#
# 차량 종류(승용차,트럭,SUV),보험 계약 유형(개인,법인,영업)(policy_type) 컬럼을 sklearn 의 **LabelEncoder** 로 인코딩해서 data_preset 에 저장하세요.

# %%
# (7) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 8. 데이터 분리
#
# claim_amount 을 y, 나머지를 X 로 삼아 train_test_split 으로 분리하세요.
# - test_size=0.25, random_state=7
# - 변수명: X_train, X_valid, y_train, y_valid

# %%
# (8) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 9. 스케일링
#
# StandardScaler 로 훈련/검증 데이터를 스케일링하는 코드인데, 의도한 것과 다르게 동작합니다. 무엇이 문제인지 서술하거나, 올바르게 고친 코드를 작성하세요.
#
# ```python
# from sklearn.preprocessing import StandardScaler
#
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_valid_scaled = scaler.transform(X_valid)
# # (이 버전에는 의도한 것과 다른 결과를 내는 부분이 있습니다)
# ```

# %%
# (9) 여기에 문제점 설명 또는 수정한 코드를 작성하세요

# %% [markdown]
# ## <AI 모델링>

# %% [markdown]
# ### 10. GridSearch 모델링
#
# DecisionTreeRegressor 와 RandomForestRegressor 를 GridSearchCV(cv=3)로 탐색하고 학습하세요.
# - max_depth 후보: [3, 5, 7]
# - RandomForestRegressor 의 n_estimators 후보: [50, 100, 200]
# - 변수명: gs_a (트리 모델), gs_b (앙상블 모델)

# %%
# (10) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 11. GridSearch 결과 확인
#
# 위 GridSearch에서 RandomForestRegressor 의 n_estimators 후보는 [50, 100, 200] 였습니다. GridSearchCV가 고를 수 있는 값의 후보 중 '가장 큰 값'은 얼마인가요?

# %%
# (11) 여기에 답을 입력하세요 (실행 불필요)

# %% [markdown]
# ### 12. 변수중요도
#
# RandomForestRegressor 의 변수중요도 Top 15개를 뽑아 시각화하는 코드인데, 의도한 것과 다르게 동작합니다. 무엇이 문제인지 서술하거나, 올바르게 고친 코드를 작성하세요.
#
# ```python
# fi = pd.DataFrame({'feature': X_train.columns, 'importance': gs_b.best_estimator_.feature_importances_})
# fi = fi.sort_values('importance', ascending=False)[:16]
# sns.barplot(x='importance', y='feature', data=fi)
# plt.show()
# ```

# %%
# (12) 여기에 문제점 설명 또는 수정한 코드를 작성하세요

# %% [markdown]
# ### 13. 성능평가
#
# 검증데이터로 gs_a, gs_b 두 모델의 **mean_absolute_error** 를 각각 계산해서 a_score, b_score 에 저장하세요.

# %%
# (13) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 해설
#
# 스스로 풀어본 뒤 아래에서 확인하세요. 문항 번호가 위 문제 번호와 일치합니다.

# %% [markdown]
# ### 1번 해설 - 라이브러리 임포트 [코드작성]

# %%
import sklearn as sk

# %% [markdown]
# > import ... as ... 문법으로 별칭을 지정합니다.

# %% [markdown]
# ### 2번 해설 - 데이터 로드 [코드작성]

# %%
my_data = pd.read_csv('data.csv')
my_data.head(4)

# %% [markdown]
# > pd.read_csv() 로 파일을 읽고 head() 로 상위 행을 확인합니다.

# %% [markdown]
# ### 3번 해설 - 시각화 (subplots) [빈칸채우기]

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 5))
sns.countplot(data=my_data, x='policy_type', ax=axes[0])
sns.histplot(data=my_data, x='total_claim_amount', hue='claim_amount', ax=axes[1])
plt.show()

# %% [markdown]
# > plt.subplots() 는 nrows/ncols 로 여러 축(Axes)을 한 번에 만듭니다. 정답: subplots

# %% [markdown]
# ### 4번 해설 - 시각화 (boxplot) [코드작성]

# %%
sns.boxplot(data=my_data, x='claim_amount', y='total_claim_amount')
plt.show()

# %% [markdown]
# > sns.boxplot(x=타깃, y=수치형컬럼) 형태로 그립니다.

# %% [markdown]
# ### 5번 해설 - 이상치 처리 [빈칸채우기]

# %%
q1 = my_data['total_claim_amount'].quantile(0.25)
q3 = my_data['total_claim_amount'].quantile(0.75)
iqr = q3 - q1
lower_fence = q1 - 1.0 * iqr
upper_fence = q3 + 1.0 * iqr
data_temp = my_data.drop(my_data[(my_data['total_claim_amount'] > upper_fence) | (my_data['total_claim_amount'] < lower_fence)].index)
data_temp = data_temp.drop(columns=['policy_id'])
data_temp = data_temp.reset_index(drop=True)

# %% [markdown]
# > DataFrame.drop() 은 행(기본 axis=0) 또는 열(axis=1)을 삭제합니다. 정답: drop

# %% [markdown]
# ### 6번 해설 - 결측치 처리 [오류정정]

# %%
print('결측치 처리 전')
print(data_temp.isnull().sum())
data_na = data_temp.dropna()
print('결측치 처리 후')
print(data_na.isnull().sum())

# %% [markdown]
# > [loop_control] 원본 코드는 단순히 데이터프레임을 처리하는 순차적인 흐름이었으나, 버그 코드에서는 데이터프레임의 크기를 확인하는 조건문(if)을 추가하여 로직의 흐름을 변경했습니다. 이로 인해 특정 상황에서 `dropna()` 작업이 의도치 않게 실행되거나, 데이터가 비어있을 때 예외 처리가 잘못되어 결과가 달라질 수 있습니다.

# %% [markdown]
# ### 7번 해설 - 인코딩 [코드작성]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data_preset = data_na.copy()
data_preset['policy_type'] = le.fit_transform(data_preset['policy_type'])

# %% [markdown]
# > 범주형 데이터를 숫자로 바꾸는 두 가지 방법 중 하나를 사용합니다.

# %% [markdown]
# ### 8번 해설 - 데이터 분리 [코드작성]

# %%
from sklearn.model_selection import train_test_split

X = data_preset.drop('claim_amount', axis=1)
y = data_preset['claim_amount']

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.25, random_state=7)

# %% [markdown]
# > train_test_split(X, y, ...) 은 X_train, X_valid, y_train, y_valid 순서로 반환합니다.

# %% [markdown]
# ### 9번 해설 - 스케일링 [오류정정]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_valid_scaled = scaler.transform(X_valid)

# %% [markdown]
# > [loop_control] 루프/조건 제어 착각: 조건문을 잘못 넣어 일부 로직이 건너뛰어지거나 잘못 실행됨

# %% [markdown]
# ### 10번 해설 - GridSearch 모델링 [코드작성]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

gs_a = GridSearchCV(DecisionTreeRegressor(random_state=7), {'max_depth':[3,5,7]}, cv=3)
gs_a.fit(X_train_scaled, y_train)

gs_b = GridSearchCV(RandomForestRegressor(random_state=7), {'n_estimators':[50, 100, 200], 'max_depth':[3,5,7]}, cv=3)
gs_b.fit(X_train_scaled, y_train)

# %% [markdown]
# > GridSearchCV(estimator, param_grid, cv=...).fit(X_train, y_train) 형태로 탐색합니다.

# %% [markdown]
# ### 11번 해설 - GridSearch 결과 확인 [결과값예측]

# %%
200

# %% [markdown]
# > 제시된 후보 중 GridSearch가 고를 수 있는 최댓값을 묻는 문항입니다.

# %% [markdown]
# ### 12번 해설 - 변수중요도 [오류정정]

# %%
fi = pd.DataFrame({'feature': X_train.columns, 'importance': gs_b.best_estimator_.feature_importances_})
fi = fi.sort_values('importance', ascending=False)[:15]
sns.barplot(x='importance', y='feature', data=fi)
plt.show()

# %% [markdown]
# > [off_by_one] 원래 코드는 상위 15개 특징을 선택하도록 설정되어 있지만, 오프바이원 오류를 위해 슬라이싱 범위를 16으로 변경했습니다. 이로 인해 실제로는 16개의 특징이 시각화되게 되어 의도된 개수(15개)보다 하나 더 많은 데이터가 포함됩니다.

# %% [markdown]
# ### 13번 해설 - 성능평가 [코드작성]

# %%
from sklearn.metrics import mean_absolute_error

y_pred_a = gs_a.best_estimator_.predict(X_valid_scaled)
y_pred_b = gs_b.best_estimator_.predict(X_valid_scaled)

a_score = mean_absolute_error(y_valid, y_pred_a)
b_score = mean_absolute_error(y_valid, y_pred_b)
print(a_score, b_score)

# %% [markdown]
# > sklearn.metrics.mean_absolute_error 에 (실제값, 예측값) 순서로 인자를 넣습니다.
