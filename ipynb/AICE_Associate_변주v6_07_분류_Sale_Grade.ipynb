# %% [markdown]
# # AICE Associate 변주 문제 v6 - 프리미엄, 표준 예측 (분류)

# %% [markdown]
# ### 이 문제집에서 배우는 요소 (Component 요약)
#
# 아래 다이어그램은 이 노트북에서 실제로 다루는 기법들을 단계별로 요약한 것입니다. (문제집마다 무작위로 조합이 달라집니다.)

# %%
from IPython.display import HTML, display

display(HTML("""
<script type="module">
import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10/dist/mermaid.esm.min.mjs';

mermaid.initialize({
    startOnLoad: true
});
</script>

<div class="mermaid">
graph TD
    A["📊 데이터 분석<br/>read_csv/read_json · merge · groupby · countplot/histplot · corr heatmap"]
    B["🧹 전처리<br/>이상치 제거(IQR) · 중복 제거 · 날짜파생(dayofweek/is_weekend) · 비율파생 · Binning · 결측치 처리"]
    C["🔤 인코딩/분할/스케일링<br/>OneHotEncoder(sklearn) · train_test_split(분류) · StandardScaler"]
    D["🤖 머신러닝<br/>KNeighborsClassifier(fit-predict) · GridSearchCV(cv=10): DecisionTreeClassifier vs XGBClassifier · 평가: recall_score"]
    E["🧠 딥러닝<br/>Dense/Dropout · EarlyStopping · model.fit/evaluate"]
    A --> B --> C --> D --> E
</div>
"""))

# %% [markdown]
# ### 스톱워치
#
# 아래 셀을 실행하면 경과 시간이 표시됩니다. 문제를 풀기 시작하기 전에 먼저 실행하세요.

# %%
from IPython.display import HTML, display

def show_stopwatch():
    display(HTML('''
<div id="stopwatch" style="font-size: 18px; font-weight: bold; color: #d93025; padding: 8px; border: 1px solid #d93025; border-radius: 5px; display: inline-block;">
    ⏱️ 경과 시간: <span id="time_str">00:00</span>
</div>
<script>
    var sec = 0;
    var timer = setInterval(function(){
        sec++;
        var m = Math.floor(sec / 60);
        var s = sec % 60;
        document.getElementById("time_str").innerText =
            (m < 10 ? "0" + m : m) + ":" + (s < 10 ? "0" + s : s);
    }, 1000);
</script>
'''))
show_stopwatch()

# %% [markdown]
# ### 시나리오
#
# 글로벌 식량 공급망의 불안정성으로 인해 국내 농산물 경매 가격 예측은 재고 관리 및 선제적인 시장 대응에 필수적입니다. 이 모델은 특정 시점의 수확량, 품질 등급, 그리고 지역별 수요 변동성을 분석하여 향후 해당 농산물의 예상 판매 등급(프리미엄 vs. 표준)을 분류하는 데 사용됩니다. 이를 통해 기업은 위험을 최소화하고 최적의 재고 전략을 수립할 수 있습니다.
#
# ---
#
# **[유의사항]**
# - 답안은 각 문항 아래 표시된 `# (N) ...` 칸에 작성하세요.
# - **정답/해설은 이 노트북 가장 아래 `## 해설` 섹션에 모아뒀습니다.** 먼저 스스로 풀어본 뒤에 확인하세요.
# - 문제를 다 풀면 `## 자동 채점` 셀을 실행해서 점수를 확인할 수 있습니다 (해설을 보기 전에 먼저 채점해보세요).
# - 이 노트북은 오리지널 창작 문제이며, 실제 AICE 샘플문항 원문을 복제하지 않습니다.
# - 데이터 로더: `read_json` / 기본모델: `DecisionTreeClassifier` / 비교모델: `XGBClassifier` / 스케일러: `StandardScaler`

# %% [markdown]
# **[데이터 컬럼 설명]**
#
# - Sale_Grade : 프리미엄, 표준
# - Total_Volume_Ton : 해당 경매 물량의 총 수확량 (톤)
# - Crop_Type : 작물 종류 (예: 쌀, 사과, 고추)
# - Region_Code : 생산 지역 코드 (5자리 지역별 코드값) (dim.csv 와 병합 키)
# - Harvest_Date : 피처 컬럼
# - Moisture_Level_Pct : 피처 컬럼
# - Quality_Index_Score : 피처 컬럼
# - Auction_Price_Base : 피처 컬럼
# - Auction_ID : 식별자(모델링에 불필요)
# - event_date : 이벤트 발생 날짜 (문자열, 전처리 단계에서 datetime 변환 후 파생 컬럼 추출용)
# - (병합 후) dim_value : 지역별 평균 경매 가중치

# %% [markdown]
# ## 0. 데이터 준비
#
# 다음 문항을 풀기 전에 아래 코드를 실행하세요 (문제 데이터 2개 테이블을 생성합니다).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


def synthesize_tables(seed=8006, n_rows=600):
    rng = np.random.default_rng(seed)
    n = n_rows

    base = rng.normal(loc=50, scale=15, size=n)
    outlier_idx = rng.choice(n, size=max(3, n // 50), replace=False)
    base[outlier_idx] += rng.choice([1, -1], size=len(outlier_idx)) * rng.uniform(80, 150, size=len(outlier_idx))

    main_df = pd.DataFrame({'Total_Volume_Ton': base.round(2)})

    cats = [f"Cat{i+1}" for i in range(rng.integers(3, 5))]
    main_df['Crop_Type'] = rng.choice(cats, size=n)

    n_regions = rng.integers(5, 9)
    regions = [f"R{i+1:02d}" for i in range(n_regions)]
    main_df['Region_Code'] = rng.choice(regions, size=n)

    for col in ['Harvest_Date', 'Moisture_Level_Pct', 'Quality_Index_Score', 'Auction_Price_Base']:
        main_df[col] = rng.normal(0, 1, size=n).round(2)

    main_df['Auction_ID'] = [f"ID{i:05d}" for i in range(n)]

    z = (base - base.mean()) / (base.std() + 1e-9)
    classes = ['프리미엄', '표준']
    if '분류' == "분류":
        if False and len(classes) >= 3:
            bins = np.quantile(z, [1 / 3, 2 / 3])
            idx = np.digitize(z, bins)
            main_df['Sale_Grade'] = [classes[i] for i in idx]
        else:
            prob = 1 / (1 + np.exp(-z))
            labels = (rng.random(n) < prob).astype(int)
            main_df['Sale_Grade'] = np.where(labels == 1, classes[0], classes[-1])
    else:
        noise = rng.normal(0, 5, size=n)
        main_df['Sale_Grade'] = (base * 1.5 + noise).round(2)

    for col in ['Total_Volume_Ton'] + ['Harvest_Date', 'Moisture_Level_Pct', 'Quality_Index_Score', 'Auction_Price_Base'][:1]:
        na_idx = rng.choice(n, size=int(n * 0.03), replace=False)
        main_df.loc[na_idx, col] = np.nan

    event_dates = pd.Timestamp("2023-01-01") + pd.to_timedelta(rng.integers(0, 730, size=n), unit="D")
    main_df["event_date"] = event_dates.strftime("%Y-%m-%d")

    dup_idx = rng.choice(n, size=max(2, int(n * 0.01)), replace=False)
    main_df = pd.concat([main_df, main_df.loc[dup_idx]], ignore_index=True)

    main_df = main_df.sample(frac=1, random_state=seed).reset_index(drop=True)

    dim_df = pd.DataFrame({
        'Region_Code': regions,
        "dim_value": rng.uniform(0.5, 2.0, size=n_regions).round(3),
    })
    return main_df, dim_df


main_df, dim_df = synthesize_tables()
main_df.to_json("data.json", index=False)
dim_df.to_csv("dim.csv", index=False)
print("데이터 저장 완료 - data.json:", main_df.shape, "/ dim.csv:", dim_df.shape)
main_df.head(4)

# %% [markdown]
# ## <데이터 분석>

# %% [markdown]
# ### 1. 라이브러리 임포트
#
# pandas, numpy, matplotlib.pyplot, seaborn 을 각각 pd, np, plt, sns 별칭으로 임포트하세요.

# %%
# (1) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 2. 데이터 로드 (read_csv/read_json)
#
# `data.json` 를 `pd.read_json` 로 읽어 **my_data** 에, `dim.csv` 를 `pd.read_csv` 로 읽어 **dim_data** 에 각각 할당하세요.

# %%
# (2) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 3. 결측치 확인
#
# my_data 의 `Total_Volume_Ton` 컬럼에 결측치(NaN)가 몇 개 있는지 `isna().sum()` 으로 확인하세요. 몇 개입니까?

# %%
# (3) 정답을 answer_3 변수에 저장하세요 (실행하세요)

answer_3 = ""

# %% [markdown]
# ### 4. 데이터 병합 (pd.merge)
#
# `Region_Code` 를 키로 my_data 와 dim_data 를 **left join** 하여 **data_merged** 에 저장하세요.

# %%
# (4) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 5. 데이터 집계 (groupby)
#
# `Crop_Type` 별 `Total_Volume_Ton` 의 평균을 구해 **df_grp** 에 저장하세요.

# %%
# (5) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 6. 시각화 (subplots)
#
# 작물 종류 (예: 쌀, 사과, 고추)(Crop_Type) 분포의 countplot 과, 프리미엄, 표준 별 해당 경매 물량의 총 수확량 (톤)(Total_Volume_Ton) histplot 을 나란히 그리는 코드입니다.
# 빈칸 **(A)** 에 들어갈, 여러 그래프를 한 번에 그릴 때 쓰는 matplotlib 함수 이름은?
#
# ```python
# fig, axes = plt.(A)(nrows=1, ncols=2, figsize=(12, 5))
# sns.countplot(data=data_merged, x='Crop_Type', ax=axes[0])
# sns.histplot(data=data_merged, x='Total_Volume_Ton', hue='Sale_Grade', ax=axes[1])
# plt.show()
# ```

# %%
# (6) 정답을 answer_6 변수에 저장하세요 (실행하세요)

answer_6 = ""

# %% [markdown]
# ### 7. 시각화 2
#
# 프리미엄, 표준 별 해당 경매 물량의 총 수확량 (톤)(Total_Volume_Ton) 분포를 seaborn boxplot 으로 시각화하세요.

# %%
# (7) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 8. 상관관계 히트맵
#
# 수치형 컬럼들 간의 상관관계를 `.corr()` 로 구해 **corr_df** 에 저장하고, seaborn heatmap 으로 시각화하세요.

# %%
# (8) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ## <데이터 전처리>

# %% [markdown]
# ### 9. 이상치 처리
#
# IQR 기준(K=1.5)을 벗어나는 이상치 행을 제거하고, 식별자 컬럼도 삭제해서 **data_temp** 에 저장하는 코드입니다. 빈칸 **(A)** 에 들어갈, 행을 삭제할 때 쓰는 DataFrame 메서드 이름을 파악한 뒤, 아래 코드 전체를 (A)를 채워서 작성하고 실행하세요 (이후 문항들이 data_temp 를 사용합니다).
#
# ```python
# q1 = data_merged['Total_Volume_Ton'].quantile(0.25)
# q3 = data_merged['Total_Volume_Ton'].quantile(0.75)
# iqr = q3 - q1
# lower_fence = q1 - 1.5 * iqr
# upper_fence = q3 + 1.5 * iqr
# data_temp = data_merged.(A)(data_merged[(data_merged['Total_Volume_Ton'] > upper_fence) | (data_merged['Total_Volume_Ton'] < lower_fence)].index)
# data_temp = data_temp.drop(columns=['Auction_ID'])
# data_temp = data_temp.reset_index(drop=True)
# ```

# %%
# (9) 위 코드에서 (A)를 채운 전체 코드를 작성하고 실행하세요

# %% [markdown]
# ### 10. 중복 데이터 제거
#
# data_temp 에 완전히 동일한(중복) 행이 있는지 `duplicated()` 로 개수를 확인해 **dup_count** 에 저장하고, `drop_duplicates()` 로 중복 행을 제거한 뒤 인덱스를 리셋해서 다시 **data_temp** 에 저장하세요.

# %%
# (10) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 11. 결측치 처리
#
# 다음은 data_temp 의 결측치를 대표값으로 채우는 코드인데, 실행하면 의도한 것과 다르게 동작합니다. 무엇이 문제인지 서술하거나, 올바르게 고친 코드를 작성하세요.
#
# ```python
# fill_value = data_temp['Total_Volume_Ton'].mode()[0]
# data_na = data_temp.fillna({'Total_Volume_Ton': fill_value})
# data_na['Harvest_Date'] = data_na['Harvest_Date'].fillna(data_temp['Harvest_Date'].mode()[0])
# ```

# %%
# (11) 여기에 문제점 설명 또는 수정한 코드를 작성하세요

# %% [markdown]
# ### 12. 날짜 특성 추출
#
# `event_date` 컬럼을 `pd.to_datetime()` 으로 datetime 타입으로 변환한 뒤, 요일(**day_of_week**, 0=월~6=일)과 주말 여부(**is_weekend**, 0/1) 파생 컬럼을 만들고, 원본 `event_date` 컬럼은 삭제해서 다시 data_na 에 저장하세요.

# %%
# (12) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 13. 파생 변수 생성 (비율)
#
# `Total_Volume_Ton` 값을 `Harvest_Date` 의 절댓값에 1을 더한 값으로 나눈 파생 변수를 **ratio_feature** 라는 새 컬럼으로 만들어 data_na 에 추가하세요.

# %%
# (13) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 14. 구간화 (Binning)
#
# `Total_Volume_Ton` 값을 `pd.cut()` 으로 3개 구간(Low/Medium/High)으로 나누고, 구간별 개수를 **bin_counts** 에 저장하세요 (data_na 자체는 변경하지 않아도 됩니다).

# %%
# (14) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 15. 인코딩
#
# `Crop_Type` 는 sklearn **OneHotEncoder**(drop='first')로, `Region_Code` 는 LabelEncoder 로 인코딩해서 data_preset 에 저장하세요. 타깃 컬럼 `Sale_Grade` 도 LabelEncoder 로 정수 인코딩하세요.

# %%
# (15) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 16. 데이터 분리
#
# Sale_Grade 을 y, 나머지를 X 로 삼아 train_test_split 으로 분리하세요.
# - test_size=0.2, random_state=7, stratify 옵션을 적용하세요
# - 변수명: X_train, X_valid, y_train, y_valid

# %%
# (16) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 17. 스케일링
#
# StandardScaler 로 훈련/검증 데이터를 스케일링하는 코드인데, 의도한 것과 다르게 동작합니다. 무엇이 문제인지 서술하거나, 올바르게 고친 코드를 작성하세요.
#
# ```python
# from sklearn.preprocessing import StandardScaler
#
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# if len(X_valid) > 0:
#     X_valid_scaled = scaler.transform(X_valid)
# ```

# %%
# (17) 여기에 문제점 설명 또는 수정한 코드를 작성하세요

# %% [markdown]
# ### 18. 스케일러 특성
#
# StandardScaler 를 훈련 데이터에 적용하면, 결과 값의 분포는 이론적으로 어떤 특성을 가지게 됩니까?

# %%
# (18) 정답을 answer_18 변수에 저장하세요 (실행하세요)

answer_18 = ""

# %% [markdown]
# ## <AI 모델링>

# %% [markdown]
# ### 19. 머신러닝 기본 (fit-predict)
#
# KNeighborsClassifier 로 모델을 하나 만들어 학습시키고, 검증데이터에 대한 예측값을 **pred_y** 에, `model.score(X_valid_scaled, y_valid)` 결과를 **model_score** 에 저장하세요. (변수명: model, pred_y, model_score)

# %%
# (19) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 20. GridSearch 모델링
#
# DecisionTreeClassifier 와 XGBClassifier 를 GridSearchCV(cv=10, scoring='f1_macro')로 탐색하고 학습하세요.
# - max_depth 후보: [3, 5, 7]
# - XGBClassifier 의 n_estimators 후보: [100, 200]
# - 변수명: gs_a (베이스 모델), gs_b (비교 모델)

# %%
# (20) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 21. GridSearch 결과 확인
#
# 위 GridSearch에서 XGBClassifier 의 n_estimators 후보는 [100, 200] 였습니다. GridSearchCV가 고를 수 있는 값의 후보 중 '가장 큰 값'은 얼마인가요?

# %%
# (21) 정답을 answer_21 변수에 저장하세요 (실행하세요)

answer_21 = ""

# %% [markdown]
# ### 22. 변수중요도
#
# XGBClassifier 의 변수중요도 Top 15개(정렬 ascending=False)를 뽑아 bar 차트로 시각화하는 코드인데, 의도한 것과 다르게 동작합니다. 무엇이 문제인지 서술하거나, 올바르게 고친 코드를 작성하세요.
#
# ```python
# fi = pd.DataFrame({'feature': X_train.columns, 'importance': gs_b.best_estimator_.feature_importances_})
# fi = fi.sort_values('importance', ascending=False)[:15]
# sns.barplot(x='feature', y='importance', data=fi)
# plt.show()
# # (이 버전에는 의도한 것과 다른 결과를 내는 부분이 있습니다)
# ```

# %%
# (22) 여기에 문제점 설명 또는 수정한 코드를 작성하세요

# %% [markdown]
# ### 23. 성능평가
#
# 검증데이터로 gs_a, gs_b 두 모델의 **recall_score** 를 각각 계산해서 a_score, b_score 에 저장하세요 (타깃이 문자열/다중 클래스이므로 average='macro' 를 함께 쓰세요).

# %%
# (23) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 24. 모델 성능 비교
#
# 바로 위에서 계산한 a_score 와 b_score 를 비교했을 때, 어느 모델이 더 우수하다고 판단할 수 있습니까? (둘 중 하나를 실행 결과에 따라 답하세요)

# %%
# (24) 정답을 answer_24 변수에 저장하세요 (실행하세요)

answer_24 = ""

# %% [markdown]
# ### 25. 혼동행렬 및 분류 리포트
#
# gs_b(XGBClassifier)의 검증데이터 예측값으로 confusion_matrix 를 구해 **cm** 에 저장하고 heatmap 으로 시각화한 뒤, classification_report 를 출력하세요.

# %%
# (25) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 26. 딥러닝 설계
#
# 다음은 딥러닝 모델을 설계하는 코드입니다. EarlyStopping 에서 '몇 epoch 동안 개선이 없으면 멈출지' 지정하는 파라미터 이름(빈칸 **(A)**)을 파악한 뒤, 아래 코드 전체를 (A)를 채워서 작성하고 실행하세요 (이후 문항들이 model/cb_list 를 사용합니다). (은닉층 활성함수: relu, 출력층: sigmoid/binary_crossentropy)
#
# ```python
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Dropout
# from tensorflow.keras.callbacks import EarlyStopping
#
# model = Sequential([
#     Dense(64, activation='relu'),
#     Dropout(0.3),
#     Dense(32, activation='relu'),
#     Dropout(0.3),
#     Dense(1, activation='sigmoid')
# ])
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# cb_list = [EarlyStopping(monitor='val_loss', (A)=10, restore_best_weights=True)]
# ```

# %%
# (26) 위 코드에서 (A)를 채운 전체 코드를 작성하고 실행하세요

# %% [markdown]
# ### 27. 딥러닝 학습
#
# 위에서 설계한 model 을 batch_size=16, epochs=50 으로 학습하고 history 에 저장하세요 (callbacks=cb_list 사용). 이어서 `model.evaluate(X_valid_scaled, y_valid)` 로 검증 손실/지표를 **eval_loss**, **eval_metric** 에 저장하세요.

# %%
# (27) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ### 28. 학습곡선 시각화
#
# history 를 이용해서 학습/검증 **accuracy** 변화를 한 그래프에 시각화하세요 (x축 라벨: epoch, 범례 위치: upper left, 범례 텍스트: train/val).

# %%
# (28) 여기에 답안코드를 작성하고 실행하세요

# %% [markdown]
# ---
# ## 자동 채점
#
# 위 문항을 모두 풀고 실행한 뒤, 아래 셀을 실행해서 점수를 확인하세요. (딥러닝 문항은 tensorflow 가 필요하므로 Colab 에서 실행했을 때만 채점됩니다.)

# %%
_CHECKS = [(1, '라이브러리 임포트', "all(k in globals() for k in ['pd','np','plt','sns'])", '임포트 확인됨', 'pd/np/plt/sns 임포트가 필요합니다'), (2, '데이터 로드 (read_csv/read_json)', "'my_data' in globals() and tuple(getattr(my_data,'shape',())) == (606, 10) and 'dim_data' in globals() and tuple(getattr(dim_data,'shape',())) == (7, 2)", 'shape 일치', 'my_data shape (606, 10), dim_data shape (7, 2) 이어야 합니다'), (3, '결측치 확인', "_norm_answer(globals().get('answer_3')) == '18'", '정답 일치', '정답은 18 입니다'), (4, '데이터 병합 (pd.merge)', "'data_merged' in globals() and tuple(getattr(data_merged,'shape',())) == (606, 11)", 'shape 일치', 'data_merged shape (606, 11) 이어야 합니다'), (5, '데이터 집계 (groupby)', "'df_grp' in globals() and sorted(str(x) for x in getattr(df_grp,'index',[])) == ['Cat1', 'Cat2', 'Cat3', 'Cat4']", '그룹 일치', 'df_grp 의 그룹(index)이 올바르지 않습니다'), (6, '시각화 (subplots)', "_norm_answer(globals().get('answer_6')) == 'subplots'", '정답 일치', '정답은 subplots 입니다'), (9, '이상치 처리', "'data_temp' in globals() and tuple(getattr(data_temp,'shape',())) == (586, 10)", 'shape 일치', 'data_temp shape (586, 10) 이어야 합니다 ((A)=drop, 전체 코드를 실행했는지 확인)'), (11, '결측치 처리', "'data_na' in globals() and int(data_na.isna().sum().sum()) == 0 and tuple(getattr(data_na,'shape',())) == (586, 12)", '결측치 제거 및 shape 일치', '결측치가 남아있거나 shape 이 올바르지 않습니다'), (15, '인코딩', "'data_preset' in globals() and data_preset.select_dtypes(include='object').shape[1] == 0 and tuple(getattr(data_preset,'shape',())) == (586, 14)", '인코딩 및 shape 일치', '문자열(object) 컬럼이 남아있거나 shape 이 올바르지 않습니다'), (16, '데이터 분리', "all(k in globals() for k in ['X_train','X_valid','y_train','y_valid']) and len(X_train) == 468 and len(X_valid) == 118", '분리 크기 일치', 'X_train/X_valid 길이가 468/118 이어야 합니다'), (17, '스케일링', "'X_train_scaled' in globals() and 'X_valid_scaled' in globals() and len(X_train_scaled) == len(X_train) and len(X_valid_scaled) == len(X_valid)", '스케일링 변수 확인', 'X_train_scaled/X_valid_scaled 를 올바르게 생성했는지 확인하세요'), (18, '스케일러 특성', "len(_norm_answer(globals().get('answer_18'))) > 2", '답변 작성됨 (해설과 비교해 직접 확인하세요)', 'answer_18 가 비어있습니다'), (19, '머신러닝 기본 (fit-predict)', "'model' in globals() and hasattr(model,'predict') and 'pred_y' in globals() and len(pred_y) == len(X_valid) and 'model_score' in globals() and isinstance(model_score,(int,float))", 'model/pred_y/model_score 확인', 'model, pred_y, model_score(=model.score(X_valid,y_valid)) 를 올바르게 생성했는지 확인하세요'), (8, '상관관계 히트맵', "'corr_df' in globals() and hasattr(corr_df,'shape') and corr_df.shape[0] == corr_df.shape[1]", 'corr_df 확인', 'corr_df 를 정사각형 상관계수 행렬로 생성했는지 확인하세요'), (25, '혼동행렬 및 분류 리포트', "'cm' in globals() and hasattr(cm,'shape')", 'cm 확인', 'confusion_matrix 결과를 cm 에 저장했는지 확인하세요'), (20, 'GridSearch 모델링', "'gs_a' in globals() and hasattr(gs_a,'best_estimator_') and 'gs_b' in globals() and hasattr(gs_b,'best_estimator_')", 'gs_a/gs_b 학습 확인', 'gs_a, gs_b 가 GridSearchCV로 학습되었는지 확인하세요'), (21, 'GridSearch 결과 확인', "_norm_answer(globals().get('answer_21')) == '200'", '정답 일치', '정답은 200 입니다'), (22, '변수중요도', "'fi' in globals() and set(['feature','importance']).issubset(set(fi.columns)) and len(fi) == 13", 'fi 구조 확인', 'fi 에 feature/importance 컬럼과 올바른 길이가 필요합니다'), (23, '성능평가', "'a_score' in globals() and 'b_score' in globals() and isinstance(a_score,(int,float)) and isinstance(b_score,(int,float))", 'a_score/b_score 확인', 'a_score, b_score 를 숫자로 계산했는지 확인하세요'), (24, '모델 성능 비교', "len(_norm_answer(globals().get('answer_24'))) > 0", '답변 작성됨 (해설과 비교해 직접 확인하세요)', 'answer_24 가 비어있습니다'), (26, '딥러닝 설계', "_norm_answer(globals().get('answer_26')) == 'patience' and 'model' in globals() and hasattr(model,'fit') and 'cb_list' in globals()", '정답 및 model/cb_list 확인', "answer_26 는 'patience' 여야 하고, model/cb_list 도 함께 생성해야 합니다 (Colab 실행 필요)"), (27, '딥러닝 학습', "'history' in globals() and hasattr(history,'history') and 'eval_loss' in globals() and 'eval_metric' in globals()", 'history/eval_loss/eval_metric 확인 (Colab 실행 필요)', 'history, eval_loss, eval_metric(=model.evaluate 결과) 를 생성했는지 확인하세요 (Colab 실행 필요)'), (10, '중복 데이터 제거', "'data_temp' in globals() and int(data_temp.duplicated().sum()) == 0 and 'dup_count' in globals()", '중복 제거 확인', 'dup_count 를 계산하고 data_temp 의 중복 행을 제거했는지 확인하세요'), (12, '날짜 특성 추출', "'data_na' in globals() and 'day_of_week' in data_na.columns and 'is_weekend' in data_na.columns and 'event_date' not in data_na.columns", '날짜 파생 컬럼 확인', 'day_of_week/is_weekend 컬럼을 만들고 event_date 원본 컬럼을 삭제했는지 확인하세요'), (13, '파생 변수 생성 (비율)', "'data_na' in globals() and 'ratio_feature' in data_na.columns", 'ratio_feature 확인', 'ratio_feature 컬럼을 생성했는지 확인하세요'), (14, '구간화 (Binning)', "'bin_counts' in globals() and len(bin_counts) == 3", 'bin_counts 확인', '3개 구간으로 나눈 bin_counts 를 생성했는지 확인하세요')]

def _norm_answer(x):
    if x is None:
        return ""
    try:
        return str(x).strip().strip('"\'').lower()
    except Exception:
        return ""

_score = 0
_total = 0
_report = []
for _n, _title, _cond, _ok_msg, _fail_msg in _CHECKS:
    _total += 1
    try:
        _result = bool(eval(_cond))
    except Exception:
        _result = False
    if _result:
        _score += 1
        _report.append(f"[PASS] {_n}번 {_title}: {_ok_msg}")
    else:
        _report.append(f"[FAIL] {_n}번 {_title}: {_fail_msg}")

print("\n".join(_report))
print(f"\n총점: {_score} / {_total}  ({_score/_total*100:.0f}점)" if _total else "채점 가능한 문항이 없습니다")

# %% [markdown]
# ---
# ## 해설
#
# 채점 후 아래에서 정답과 설명을 확인하세요. 문항 번호가 위 문제 번호와 일치합니다.

# %% [markdown]
# ### 1번 해설 - 라이브러리 임포트 [코드작성]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# > import ... as ... 문법으로 널리 쓰이는 관례적 별칭을 지정합니다.

# %% [markdown]
# ### 2번 해설 - 데이터 로드 (read_csv/read_json) [코드작성]

# %%
my_data = pd.read_json('data.json')
dim_data = pd.read_csv('dim.csv')
my_data.head(4)

# %% [markdown]
# > pd.read_json() 로 파일 형식에 맞는 로더를 사용합니다.

# %% [markdown]
# ### 3번 해설 - 결측치 확인 [결과값예측]

# %%
18

# %% [markdown]
# > Series.isna().sum() 은 True(결측치)의 개수를 셉니다.

# %% [markdown]
# ### 4번 해설 - 데이터 병합 (pd.merge) [코드작성]

# %%
data_merged = pd.merge(my_data, dim_data, on='Region_Code', how='left')
data_merged.head(4)

# %% [markdown]
# > pd.merge(left, right, on=키, how='left') 는 왼쪽 테이블 기준으로 오른쪽 테이블을 결합합니다.

# %% [markdown]
# ### 5번 해설 - 데이터 집계 (groupby) [코드작성]

# %%
df_grp = data_merged.groupby('Crop_Type')['Total_Volume_Ton'].mean()
df_grp

# %% [markdown]
# > groupby(기준컬럼)[대상컬럼].mean() 형태로 그룹별 집계를 구합니다.

# %% [markdown]
# ### 6번 해설 - 시각화 (subplots) [빈칸채우기]

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 5))
sns.countplot(data=data_merged, x='Crop_Type', ax=axes[0])
sns.histplot(data=data_merged, x='Total_Volume_Ton', hue='Sale_Grade', ax=axes[1])
plt.show()

# %% [markdown]
# > plt.subplots() 는 nrows/ncols 로 여러 축(Axes)을 한 번에 만듭니다. 정답: subplots

# %% [markdown]
# ### 7번 해설 - 시각화 2 [코드작성]

# %%
sns.boxplot(data=data_merged, x='Sale_Grade', y='Total_Volume_Ton')
plt.show()

# %% [markdown]
# > sns.boxplot(x=, y=) / sns.jointplot(x=, y=) 형태로 그립니다.

# %% [markdown]
# ### 8번 해설 - 상관관계 히트맵 [코드작성]

# %%
corr_df = data_merged.corr(numeric_only=True)
sns.heatmap(corr_df, annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# > DataFrame.corr(numeric_only=True) 로 상관계수 행렬을 구하고 sns.heatmap() 으로 시각화합니다.

# %% [markdown]
# ### 9번 해설 - 이상치 처리 [빈칸채우기]

# %%
q1 = data_merged['Total_Volume_Ton'].quantile(0.25)
q3 = data_merged['Total_Volume_Ton'].quantile(0.75)
iqr = q3 - q1
lower_fence = q1 - 1.5 * iqr
upper_fence = q3 + 1.5 * iqr
data_temp = data_merged.drop(data_merged[(data_merged['Total_Volume_Ton'] > upper_fence) | (data_merged['Total_Volume_Ton'] < lower_fence)].index)
data_temp = data_temp.drop(columns=['Auction_ID'])
data_temp = data_temp.reset_index(drop=True)

# %% [markdown]
# > DataFrame.drop() 은 행(기본 axis=0) 또는 열(axis=1)을 삭제합니다. 정답: drop

# %% [markdown]
# ### 10번 해설 - 중복 데이터 제거 [코드작성]

# %%
dup_count = data_temp.duplicated().sum()
print('중복 행 개수:', dup_count)
data_temp = data_temp.drop_duplicates().reset_index(drop=True)

# %% [markdown]
# > DataFrame.duplicated() 는 중복 여부를 불리언 Series 로 반환하며 .sum() 으로 개수를 셀 수 있습니다. drop_duplicates() 는 기본적으로 완전히 동일한 행만 제거합니다.

# %% [markdown]
# ### 11번 해설 - 결측치 처리 [오류정정]

# %%
fill_value = data_temp['Total_Volume_Ton'].mode()[0]
data_na = data_temp.fillna({'Total_Volume_Ton': fill_value})
data_na['Harvest_Date'] = data_na['Harvest_Date'].fillna(data_na['Harvest_Date'].mode()[0])

# %% [markdown]
# > [scope_reference] 두 번째 결측치 채우기 시, `data_na`의 모드를 사용해야 하는데 실수로 원본 데이터프레임인 `data_temp`의 모드를 참조했습니다. 이는 데이터 흐름(scope)에서 일관성이 깨져 의도하지 않은 값으로 채워질 수 있습니다.

# %% [markdown]
# ### 12번 해설 - 날짜 특성 추출 [코드작성]

# %%
data_na['event_date'] = pd.to_datetime(data_na['event_date'])
data_na['day_of_week'] = data_na['event_date'].dt.dayofweek
data_na['is_weekend'] = data_na['day_of_week'].isin([5, 6]).astype(int)
data_na = data_na.drop(columns=['event_date'])
data_na[['day_of_week', 'is_weekend']].head()

# %% [markdown]
# > pd.to_datetime() 변환 후 .dt 접근자로 dayofweek 등 날짜 파생값을 뽑아낼 수 있습니다. 원본 문자열 날짜 컬럼은 모델 입력으로 쓸 수 없으므로 파생 컬럼을 만든 뒤 삭제합니다.

# %% [markdown]
# ### 13번 해설 - 파생 변수 생성 (비율) [코드작성]

# %%
data_na['ratio_feature'] = data_na['Total_Volume_Ton'] / (data_na['Harvest_Date'].abs() + 1)
data_na[['ratio_feature']].describe()

# %% [markdown]
# > 두 수치형 컬럼을 조합해 새로운 파생 변수(비율/상호작용 특성)를 만드는 특성공학 기법입니다.

# %% [markdown]
# ### 14번 해설 - 구간화 (Binning) [코드작성]

# %%
numeric_col_bin = pd.cut(data_na['Total_Volume_Ton'], bins=3, labels=['Low', 'Medium', 'High'])
bin_counts = numeric_col_bin.value_counts()
print(bin_counts)

# %% [markdown]
# > pd.cut(컬럼, bins=N, labels=[...]) 은 값의 범위를 N개의 동일 너비 구간으로 나눕니다 (qcut은 분위수 기준이라 값이 중복될 때 오류가 날 수 있어, 균등폭 구간에는 cut을 흔히 씁니다).

# %% [markdown]
# ### 15번 해설 - 인코딩 [코드작성]

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

ohe = OneHotEncoder(sparse_output=False, drop='first')
encoded = ohe.fit_transform(data_na[['Crop_Type']])
encoded_df = pd.DataFrame(encoded, columns=ohe.get_feature_names_out(['Crop_Type']), index=data_na.index)
data_preset = pd.concat([data_na.drop(columns=['Crop_Type']), encoded_df], axis=1)

le = LabelEncoder()
data_preset['Region_Code'] = le.fit_transform(data_preset['Region_Code'])
from sklearn.preprocessing import LabelEncoder as _TargetLE
data_preset['Sale_Grade'] = _TargetLE().fit_transform(data_preset['Sale_Grade'])
data_preset.info()

# %% [markdown]
# > 저-카디널리티는 원-핫, 코드성 범주는 라벨 인코딩을 흔히 사용합니다. 타깃 컬럼도 XGBoost/LightGBM 등 일부 모델은 문자열 클래스를 그대로 받아들이지 않으므로, `Sale_Grade` 도 함께 LabelEncoder 로 0/1(다중클래스는 0..N-1) 정수로 인코딩합니다.

# %% [markdown]
# ### 16번 해설 - 데이터 분리 [코드작성]

# %%
from sklearn.model_selection import train_test_split

X = data_preset.drop(['Sale_Grade'], axis=1)
y = data_preset['Sale_Grade']

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=7, stratify=y)

# %% [markdown]
# > train_test_split(X, y, ...) 은 X_train, X_valid, y_train, y_valid 순서로 반환합니다.

# %% [markdown]
# ### 17번 해설 - 스케일링 [오류정정]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_valid_scaled = scaler.transform(X_valid)

# %% [markdown]
# > [loop_control] 원래 코드는 학습 데이터와 검증 데이터 모두에 대해 스케일링을 수행하지만, 버그된 코드에서는 검증 데이터의 크기를 확인하는 조건문이 추가되었습니다. 이 조건문 때문에 X_valid가 비어있을 경우 X_valid_scaled 변수가 정의되지 않아 로직이 건너뛰어질 수 있습니다.

# %% [markdown]
# ### 18번 해설 - 스케일러 특성 [결과값예측]

# %%
'평균(mean) 0, 표준편차(std) 1에 가까워집니다 (Z-score 표준화).'

# %% [markdown]
# > StandardScaler 의 정의에 따른 이론적 특성입니다.

# %% [markdown]
# ### 19번 해설 - 머신러닝 기본 (fit-predict) [코드작성]

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train_scaled, y_train)
pred_y = model.predict(X_valid_scaled)
model_score = model.score(X_valid_scaled, y_valid)
print(pred_y[:5], model_score)

# %% [markdown]
# > import → model = 클래스() → model.fit(X_train, y_train) → pred_y = model.predict(X_valid) → model.score(X_valid, y_valid) 5줄 템플릿입니다. score() 는 분류=accuracy, 회귀=R² 를 반환합니다.

# %% [markdown]
# ### 20번 해설 - GridSearch 모델링 [코드작성]

# %%
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV

gs_a = GridSearchCV(DecisionTreeClassifier(random_state=7), {'max_depth':[3,5,7]}, cv=10, scoring='f1_macro')
gs_a.fit(X_train_scaled, y_train)

gs_b = GridSearchCV(XGBClassifier(random_state=7), {'n_estimators':[100, 200], 'max_depth':[3,5,7]}, cv=10, scoring='f1_macro')
gs_b.fit(X_train_scaled, y_train)

# %% [markdown]
# > GridSearchCV(estimator, param_grid, cv=...).fit(X_train, y_train) 형태로 탐색합니다. XGBClassifier 는 sklearn 기본 앙상블 외에 XGBoost/LightGBM 계열일 수도 있습니다.

# %% [markdown]
# ### 21번 해설 - GridSearch 결과 확인 [결과값예측]

# %%
200

# %% [markdown]
# > 제시된 후보 중 GridSearch가 고를 수 있는 최댓값을 묻는 문항입니다.

# %% [markdown]
# ### 22번 해설 - 변수중요도 [오류정정]

# %%
fi = pd.DataFrame({'feature': X_train.columns, 'importance': gs_b.best_estimator_.feature_importances_})
fi = fi.sort_values('importance', ascending=False)[:15]
sns.barplot(x='feature', y='importance', data=fi)
plt.show()

# %% [markdown]
# > [operator_precedence] 연산자 우선순위/형변환 착각: 정수 나눗셈, 불필요한 나눗셈·곱셈 등으로 값이 왜곡됨

# %% [markdown]
# ### 23번 해설 - 성능평가 [코드작성]

# %%
from sklearn.metrics import recall_score

y_pred_a = gs_a.best_estimator_.predict(X_valid_scaled)
y_pred_b = gs_b.best_estimator_.predict(X_valid_scaled)

a_score = recall_score(y_valid, y_pred_a, average='macro')
b_score = recall_score(y_valid, y_pred_b, average='macro')
print(a_score, b_score)

# %% [markdown]
# > sklearn.metrics.recall_score 에 (실제값, 예측값) 순서로 인자를 넣습니다.

# %% [markdown]
# ### 24번 해설 - 모델 성능 비교 [결과값예측]

# %%
'실행 결과에 따라 달라집니다: 값이 더 큰 쪽 이 더 우수한 모델입니다. a_score, b_score 를 직접 비교해서 판단하세요.'

# %% [markdown]
# > 정확도/F1/ROC-AUC 등은 높을수록, MAE/MSE 등 오차 지표는 낮을수록 좋은 성능입니다.

# %% [markdown]
# ### 25번 해설 - 혼동행렬 및 분류 리포트 [코드작성]

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_pred_b = gs_b.best_estimator_.predict(X_valid_scaled)
cm = confusion_matrix(y_valid, y_pred_b)
sns.heatmap(cm, annot=True, fmt='d')
plt.show()
print(classification_report(y_valid, y_pred_b))

# %% [markdown]
# > confusion_matrix(실제값, 예측값) 은 클래스별 정오답 개수를, classification_report 는 precision/recall/f1 을 클래스별로 요약해 보여줍니다.

# %% [markdown]
# ### 26번 해설 - 딥러닝 설계 [빈칸채우기]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential([
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
cb_list = [EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)]

# %% [markdown]
# > EarlyStopping(patience=N) 은 N번 연속 개선이 없으면 학습을 멈춥니다. 정답: patience

# %% [markdown]
# ### 27번 해설 - 딥러닝 학습 [코드작성]

# %%
history = model.fit(X_train_scaled, y_train, epochs=50, batch_size=16,
                    validation_data=(X_valid_scaled, y_valid), callbacks=cb_list)

eval_loss, eval_metric = model.evaluate(X_valid_scaled, y_valid)
print('검증 loss:', eval_loss, '/ 검증 metric:', eval_metric)

# %% [markdown]
# > model.fit(X, y, epochs=, batch_size=, validation_data=, callbacks=) 형태입니다. model.evaluate(X, y) 는 (loss, metric) 튜플을 반환합니다.

# %% [markdown]
# ### 28번 해설 - 학습곡선 시각화 [코드작성]

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# > history.history[지표] 로 epoch별 기록을 꺼내 plt.plot() + plt.legend(loc=...) 으로 그립니다.
